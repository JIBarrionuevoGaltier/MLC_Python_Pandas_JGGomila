# %% [markdown]
# # Data Wangling

# %% [markdown]
# Hecho el análisis, comenzamos a tomar decisiones de cortado de dataset, imputación de datos, ver si tomamos todo o algunos datos, etc. \
# El **data wrangling**, a veces denominada **data munging**, es el proceso de transformar y mapear datos de un dataset **raw** (en bruto) en otro formato con la intención de hacerlo más apropiado y valioso para una variedad de propósitos posteriores, como el análisis. Un ***data wrangler*** es una persona que realiza estas operaciones de transformación. \
# Esto puede incluir munging, visualización de datos, agregación de datos, entrenamiento de un modelo estadístico, así como muchos otros usos potenciales. La oscilación de datos como proceso generalmente sigue un conjunto de pasos generales que comienzan extrayendo los datos en forma cruda del origen de datos, dividiendo los datos en bruto usando algoritmos (por ejemplo, clasificación) o analizando los datos en estructuras de datos predefinidas, y finalmente depositando el contenido resultante en un sistema de almacenamiento (o silo) para su uso futuro.

# %%
import pandas as pd

# %%
data = pd.read_csv('../datasets/customer-churn-model/Customer Churn Model.txt') 
data.head()
# Out:
#   State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0    KS             128        415  382-4657         no        yes
# 1    OH             107        415  371-7191         no        yes
# 2    NJ             137        415  358-1921         no         no
# 3    OH              84        408  375-9999        yes         no
# 4    OK              75        415  330-6626        yes         no
#
#    VMail Message  Day Mins  Day Calls  Day Charge  ...  Eve Calls  Eve Charge  \
# 0             25     265.1        110       45.07  ...         99       16.78
# 1             26     161.6        123       27.47  ...        103       16.62
# 2              0     243.4        114       41.38  ...        110       10.30
# 3              0     299.4         71       50.90  ...         88        5.26
# 4              0     166.7        113       28.34  ...        122       12.61
#
#    Night Mins  Night Calls  Night Charge  Intl Mins  Intl Calls  Intl Charge  \
# 0       244.7           91         11.01       10.0           3         2.70
# 1       254.4          103         11.45       13.7           3         3.70
# 2       162.6          104          7.32       12.2           5         3.29
# 3       196.9           89          8.86        6.6           7         1.78
# 4       186.9          121          8.41       10.1           3         2.73
#
#    CustServ Calls  Churn?
# 0               1  False.
# 1               1  False.
# 2               0  False.
# 3               2  False.
# 4               3  False.
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Subconjuntos

# %% [markdown]
# Tomamos de nuestro datalake o de nuestro dataframe, las columnas, o variables que necesitamos

# %%
account_length = data['Account Length']
account_length.head()
# Out:
# 0    128
# 1    107
# 2    137
# 3     84
# 4     75
# Name: Account Length, dtype: int64

# %%
type(account_length)
# Out:
# pandas.core.series.Series

# %%
data.columns.values
# Out:
# array(['State', 'Account Length', 'Area Code', 'Phone', "Int'l Plan",
#        'VMail Plan', 'VMail Message', 'Day Mins', 'Day Calls',
#        'Day Charge', 'Eve Mins', 'Eve Calls', 'Eve Charge', 'Night Mins',
#        'Night Calls', 'Night Charge', 'Intl Mins', 'Intl Calls',
#        'Intl Charge', 'CustServ Calls', 'Churn?'], dtype=object)

# %%
subset = data[['Account Length', 'Phone', 'Eve Calls', 'Day Calls']]
subset.head()
# Out:
#    Account Length     Phone  Eve Calls  Day Calls
# 0             128  382-4657         99        110
# 1             107  371-7191        103        123
# 2             137  358-1921        110        114
# 3              84  375-9999         88         71
# 4              75  330-6626        122        113

# %%
type(subset)
# Out:
# pandas.core.frame.DataFrame

# %%
desired_columns = ['Account Length', 'Phone', 'Eve Calls', 'Day Calls']
subset = data[desired_columns]
subset.head()
# Out:
#    Account Length     Phone  Eve Calls  Day Calls
# 0             128  382-4657         99        110
# 1             107  371-7191        103        123
# 2             137  358-1921        110        114
# 3              84  375-9999         88         71
# 4              75  330-6626        122        113

# %% [markdown]
# Otra técnica, cuando tenemos un conjunto de datos con muchas variables, es sacar las que no queremos.

# %%
desired_columns = ['Account Length', 'VMail Message', 'Day Calls']
desired_columns
# Out:
# ['Account Length', 'VMail Message', 'Day Calls']

# %%
all_columns_list = data.columns.values.tolist()
all_columns_list
# Out:
# ['State',
#  'Account Length',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'VMail Message',
#  'Day Mins',
#  'Day Calls',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
sublist = [ x for x in all_columns_list if x not in desired_columns ]
sublist
# Out:
# ['State',
#  'Area Code',
#  'Phone',
#  "Int'l Plan",
#  'VMail Plan',
#  'Day Mins',
#  'Day Charge',
#  'Eve Mins',
#  'Eve Calls',
#  'Eve Charge',
#  'Night Mins',
#  'Night Calls',
#  'Night Charge',
#  'Intl Mins',
#  'Intl Calls',
#  'Intl Charge',
#  'CustServ Calls',
#  'Churn?']

# %%
subset = data[sublist]
subset.head()
# Out:
#   State  Area Code     Phone Int'l Plan VMail Plan  Day Mins  Day Charge  \
# 0    KS        415  382-4657         no        yes     265.1       45.07
# 1    OH        415  371-7191         no        yes     161.6       27.47
# 2    NJ        415  358-1921         no         no     243.4       41.38
# 3    OH        408  375-9999        yes         no     299.4       50.90
# 4    OK        415  330-6626        yes         no     166.7       28.34
#
#    Eve Mins  Eve Calls  Eve Charge  Night Mins  Night Calls  Night Charge  \
# 0     197.4         99       16.78       244.7           91         11.01
# 1     195.5        103       16.62       254.4          103         11.45
# 2     121.2        110       10.30       162.6          104          7.32
# 3      61.9         88        5.26       196.9           89          8.86
# 4     148.3        122       12.61       186.9          121          8.41
#
#    Intl Mins  Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0       10.0           3         2.70               1  False.
# 1       13.7           3         3.70               1  False.
# 2       12.2           5         3.29               0  False.
# 3        6.6           7         1.78               2  False.
# 4       10.1           3         2.73               3  False.

# %% [markdown]
# Otra forma puede ser

# %%
a = set(desired_columns)
b = set(all_columns_list)
sublist = b-a
sublist = list(sublist)

# %%
data[sublist]
# Out:
#          Phone  Day Mins  Churn?  Eve Calls  Intl Calls  CustServ Calls  \
# 0     382-4657     265.1  False.         99           3               1
# 1     371-7191     161.6  False.        103           3               1
# 2     358-1921     243.4  False.        110           5               0
# 3     375-9999     299.4  False.         88           7               2
# 4     330-6626     166.7  False.        122           3               3
# ...        ...       ...     ...        ...         ...             ...
# 3328  414-4276     156.2  False.        126           6               2
# 3329  370-3271     231.1  False.         55           4               3
# 3330  328-8230     180.8  False.         58           6               2
# 3331  364-6381     213.8  False.         84          10               2
# 3332  400-4344     234.4  False.         82           4               0
#
#       Night Mins  Intl Charge  Intl Mins  Area Code  Night Charge VMail Plan  \
# 0          244.7         2.70       10.0        415         11.01        yes
# 1          254.4         3.70       13.7        415         11.45        yes
# 2          162.6         3.29       12.2        415          7.32         no
# 3          196.9         1.78        6.6        408          8.86         no
# 4          186.9         2.73       10.1        415          8.41         no
# ...          ...          ...        ...        ...           ...        ...
# 3328       279.1         2.67        9.9        415         12.56        yes
# 3329       191.3         2.59        9.6        415          8.61         no
# 3330       191.9         3.81       14.1        510          8.64         no
# 3331       139.2         1.35        5.0        510          6.26         no
# 3332       241.4         3.70       13.7        415         10.86        yes
#
#       Night Calls State  Eve Charge Int'l Plan  Day Charge  Eve Mins
# 0              91    KS       16.78         no       45.07     197.4
# 1             103    OH       16.62         no       27.47     195.5
# 2             104    NJ       10.30         no       41.38     121.2
# 3              89    OH        5.26        yes       50.90      61.9
# 4             121    OK       12.61        yes       28.34     148.3
# ...           ...   ...         ...        ...         ...       ...
# 3328           83    AZ       18.32         no       26.55     215.5
# 3329          123    WV       13.04         no       39.29     153.4
# 3330           91    RI       24.55         no       30.74     288.8
# 3331          137    CT       13.57        yes       36.35     159.6
# 3332           77    TN       22.60         no       39.85     265.9
#
# [3333 rows x 18 columns]
